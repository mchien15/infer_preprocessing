# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from temp_image import main

# %%
def four_point_transform(image, pts):

    pts = np.float32(pts)
    (tl, tr, br, bl) = pts

    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))

    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))

    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype="float32")
    M = cv2.getPerspectiveTransform(pts, dst)
    warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))

    return warped

# %%
# CHANGE THESE PATHS TO YOUR OWN
###############################################################
input_folder = '/home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124'
output_folder = '/home/asus/infer_preprocessing/out_file/heic_fol/130124'

# %%
try:
    for image_file in os.listdir(input_folder):
        image_path = os.path.join(input_folder, image_file)

        print('-'*30)
        print(f'Processing {image_path}')

        input_image = cv2.imread(image_path)

        pil_image = main(image_path)
        # print(type(pil_image))
        img = cv2.cvtColor(np.array(pil_image), cv2.COLOR_RGB2BGR)

        cv2.imwrite(os.path.join(output_folder, image_file), img)
except Exception:
    pass
# Out:
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5283.JPG
# Loaded IMG_5283.JPG at size='532x703' --> resized='532x703'
# 703 532
#   got 83 spans with 324 points.
#   initial objective is 0.0011489852928899644
#   optimizing 415 parameters...
#   optimization took 0.28 sec.
#   final objective is 0.00113
#   got page dims 1.457890445743647 x 1.8869281020526578
#   output will be 528x672
# Total preprocess time: 0.64980s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5279.JPG
# Loaded IMG_5279.JPG at size='548x708' --> resized='548x708'
# 708 548
#   got 73 spans with 255 points.
#   initial objective is 0.0011069818334850838
#   optimizing 336 parameters...
#   optimization took 1.05 sec.
#   final objective is 0.00099
#   got page dims 1.497751865434228 x 1.8914166322591048
#   output will be 544x672
# Total preprocess time: 1.38506s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5380.JPG
# Loaded IMG_5380.JPG at size='538x666' --> resized='538x666'
# 666 538
#   got 80 spans with 298 points.
#   initial objective is 0.001119541780945512
#   optimizing 386 parameters...
#   optimization took 0.15 sec.
#   final objective is 0.0011
#   got page dims 1.5558638011813377 x 1.8799396846629224
#   output will be 544x640
# Total preprocess time: 0.46849s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5253.JPG
# Loaded IMG_5253.JPG at size='538x684' --> resized='538x684'
# 684 538
#   got 70 spans with 276 points.
#   initial objective is 0.0010818954371668416
#   optimizing 354 parameters...
#   optimization took 0.13 sec.
#   final objective is 0.00108
#   got page dims 1.5180399466483325 x 1.8856908938887087
#   output will be 528x656
# Total preprocess time: 0.37193s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5214.JPG
# Loaded IMG_5214.JPG at size='541x683' --> resized='541x683'
# 683 541
#   got 65 spans with 260 points.
#   initial objective is 0.0010343337452847145
#   optimizing 333 parameters...
#   optimization took 0.11 sec.
#   final objective is 0.00103
#   got page dims 1.5284948217523868 x 1.8851263037499424
#   output will be 544x656
# Total preprocess time: 0.32553s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5333.JPG
# Loaded IMG_5333.JPG at size='521x680' --> resized='521x680'
# 680 521
#   got 26 spans with 103 points.
#   initial objective is 0.0004373946427454109
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5247.JPG
# Loaded IMG_5247.JPG at size='546x697' --> resized='546x697'
# 697 546
#   got 66 spans with 263 points.
#   initial objective is 0.0009998305570976139
#   optimizing 337 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.001
#   got page dims 1.511633426469873 x 1.8869886368472577
#   output will be 544x672
# Total preprocess time: 0.35421s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5232.JPG
# Loaded IMG_5232.JPG at size='546x684' --> resized='546x684'
# 684 546
#   got 20 spans with 154 points.
#   initial objective is 0.0011666955429134509
#   optimizing 182 parameters...
#   optimization took 0.31 sec.
#   final objective is 0.00108
#   got page dims 1.5473744564794738 x 1.8853237081280685
#   output will be 544x656
# Total preprocess time: 0.36288s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5399.JPG
# Loaded IMG_5399.JPG at size='546x654' --> resized='546x654'
# 654 546
#   got 39 spans with 234 points.
#   initial objective is 0.0014557332776269738
#   optimizing 281 parameters...
#   optimization took 0.68 sec.
#   final objective is 0.00133
#   got page dims 1.6139190753180641 x 1.8794324768794002
#   output will be 544x624
# Total preprocess time: 0.78523s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5245.JPG
# Loaded IMG_5245.JPG at size='541x681' --> resized='541x681'
# 681 541
#   got 78 spans with 296 points.
#   initial objective is 0.001235589077846374
#   optimizing 382 parameters...
#   optimization took 0.22 sec.
#   final objective is 0.00121
#   got page dims 1.5297397405977622 x 1.8820164422058914
#   output will be 528x640
# Total preprocess time: 0.52431s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5329.JPG
# Loaded IMG_5329.JPG at size='549x698' --> resized='549x698'
# 698 549
#   got 68 spans with 291 points.
#   initial objective is 0.0014099178355957737
#   optimizing 367 parameters...
#   optimization took 0.44 sec.
#   final objective is 0.00137
#   got page dims 1.5235864594715758 x 1.8918608008674707
#   output will be 544x672
# Total preprocess time: 0.69301s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5356.JPG
# Loaded IMG_5356.JPG at size='548x685' --> resized='548x685'
# 685 548
#   got 70 spans with 261 points.
#   initial objective is 0.001136680268019548
#   optimizing 339 parameters...
#   optimization took 0.79 sec.
#   final objective is 0.00099
#   got page dims 1.5477728553423122 x 1.8895035791704435
#   output will be 544x656
# Total preprocess time: 1.07444s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5338.JPG
# Loaded IMG_5338.JPG at size='555x703' --> resized='555x703'
# 703 555
#   got 22 spans with 166 points.
#   initial objective is 0.0009331528696963968
#   optimizing 196 parameters...
#   optimization took 0.34 sec.
#   final objective is 0.00084
#   got page dims 1.5340171009251091 x 1.8933442024602163
#   output will be 544x672
# Total preprocess time: 0.39736s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5222.JPG
# Loaded IMG_5222.JPG at size='548x704' --> resized='548x704'
# 704 548
#   got 71 spans with 294 points.
#   initial objective is 0.0012382825431092965
#   optimizing 373 parameters...
#   optimization took 1.34 sec.
#   final objective is 0.00112
#   got page dims 1.504359648809987 x 1.8907475181106934
#   output will be 544x672
# Total preprocess time: 1.64878s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5248.JPG
# Loaded IMG_5248.JPG at size='546x685' --> resized='546x685'
# 685 546
#   got 20 spans with 156 points.
#   initial objective is 0.0009281896297229836
#   optimizing 184 parameters...
#   optimization took 0.22 sec.
#   final objective is 0.00089
#   got page dims 1.5425573782478739 x 1.8864567729789838
#   output will be 544x656
# Total preprocess time: 0.27611s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5391.JPG
# Loaded IMG_5391.JPG at size='532x647' --> resized='532x647'
# 647 532
#   got 23 spans with 164 points.
#   initial objective is 0.0011520594347639024
#   optimizing 195 parameters...
#   optimization took 0.32 sec.
#   final objective is 0.00108
#   got page dims 1.592583633718697 x 1.882332986552291
#   output will be 528x608
# Total preprocess time: 0.38095s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5273.JPG
# Loaded IMG_5273.JPG at size='545x700' --> resized='545x700'
# 700 545
#   got 74 spans with 238 points.
#   initial objective is 0.0009825842717078414
#   optimizing 320 parameters...
#   optimization took 0.1 sec.
#   final objective is 0.00092
#   got page dims 1.4998580113917512 x 1.885129975350126
#   output will be 544x672
# Total preprocess time: 0.39886s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5274.JPG
# Loaded IMG_5274.JPG at size='533x706' --> resized='533x706'
# 706 533
#   got 81 spans with 320 points.
#   initial objective is 0.001171791284656009
#   optimizing 409 parameters...
#   optimization took 0.18 sec.
#   final objective is 0.00115
#   got page dims 1.4562247140961124 x 1.8887042271682781
#   output will be 528x672
# Total preprocess time: 0.54005s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5276.JPG
# Loaded IMG_5276.JPG at size='538x690' --> resized='538x690'
# 690 538
#   got 66 spans with 265 points.
#   initial objective is 0.000921589932586581
#   optimizing 339 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00092
#   got page dims 1.5031687873554698 x 1.885354356626021
#   output will be 528x656
# Total preprocess time: 0.31869s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5231.JPG
# Loaded IMG_5231.JPG at size='547x669' --> resized='547x669'
# 669 547
#   got 36 spans with 196 points.
#   initial objective is 0.0012736449258053436
#   optimizing 240 parameters...
#   optimization took 0.55 sec.
#   final objective is 0.00116
#   got page dims 1.5836034230685792 x 1.8847859050133287
#   output will be 544x640
# Total preprocess time: 0.66356s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5297.JPG
# Loaded IMG_5297.JPG at size='553x695' --> resized='553x695'
# 695 553
#   got 64 spans with 236 points.
#   initial objective is 0.0008708245810966802
#   optimizing 308 parameters...
#   optimization took 0.1 sec.
#   final objective is 0.00087
#   got page dims 1.5340362380163324 x 1.884992811368413
#   output will be 544x656
# Total preprocess time: 0.32601s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5285.JPG
# Loaded IMG_5285.JPG at size='534x690' --> resized='534x690'
# 690 534
#   got 83 spans with 321 points.
#   initial objective is 0.0012233615760180604
#   optimizing 412 parameters...
#   optimization took 0.17 sec.
#   final objective is 0.00121
#   got page dims 1.4906988396305447 x 1.8845509094383914
#   output will be 528x656
# Total preprocess time: 0.48377s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5289.JPG
# Loaded IMG_5289.JPG at size='538x683' --> resized='538x683'
# 683 538
#   got 30 spans with 149 points.
#   initial objective is 0.0006869094629147957
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5292.JPG
# Loaded IMG_5292.JPG at size='544x698' --> resized='544x698'
# 698 544
#   got 74 spans with 264 points.
#   initial objective is 0.0009117184446092974
#   optimizing 346 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00089
#   got page dims 1.5035014363501962 x 1.8867641423956085
#   output will be 544x672
# Total preprocess time: 0.43073s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5337.JPG
# Loaded IMG_5337.JPG at size='541x524' --> resized='541x524'
# 524 541
#   got 31 spans with 220 points.
#   initial objective is 0.0016457742196179927
#   optimizing 259 parameters...
#   optimization took 0.63 sec.
#   final objective is 0.00156
#   got page dims 1.9345297949326334 x 1.7917992958580469
#   output will be 528x480
# Total preprocess time: 0.71152s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5238.JPG
# Loaded IMG_5238.JPG at size='538x675' --> resized='538x675'
# 675 538
#   got 38 spans with 226 points.
#   initial objective is 0.0013568206258094645
#   optimizing 272 parameters...
#   optimization took 0.62 sec.
#   final objective is 0.00124
#   got page dims 1.5444279132373302 x 1.8883762656890526
#   output will be 528x640
# Total preprocess time: 0.73526s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5261.JPG
# Loaded IMG_5261.JPG at size='533x699' --> resized='533x699'
# 699 533
#   got 80 spans with 314 points.
#   initial objective is 0.0011161116818688512
#   optimizing 402 parameters...
#   optimization took 0.27 sec.
#   final objective is 0.00109
#   got page dims 1.4694608229076855 x 1.8865699446756679
#   output will be 528x672
# Total preprocess time: 0.61238s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5363.JPG
# Loaded IMG_5363.JPG at size='538x655' --> resized='538x655'
# 655 538
#   got 19 spans with 133 points.
#   initial objective is 0.0007848439594251048
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5351.JPG
# Loaded IMG_5351.JPG at size='558x692' --> resized='558x692'
# 692 558
#   got 22 spans with 167 points.
#   initial objective is 0.001104472057786221
#   optimizing 197 parameters...
#   optimization took 0.18 sec.
#   final objective is 0.00108
#   got page dims 1.5591752434129726 x 1.8859119935862563
#   output will be 544x656
# Total preprocess time: 0.23306s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5241.JPG
# Loaded IMG_5241.JPG at size='544x656' --> resized='544x656'
# 656 544
#   got 66 spans with 256 points.
#   initial objective is 0.0009736557455039156
#   optimizing 330 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00097
#   got page dims 1.602012296507282 x 1.8817753404724327
#   output will be 544x624
# Total preprocess time: 0.37348s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5269.JPG
# Loaded IMG_5269.JPG at size='537x694' --> resized='537x694'
# 694 537
#   got 21 spans with 140 points.
#   initial objective is 0.0008666596205723359
#   optimizing 169 parameters...
#   optimization took 0.04 sec.
#   final objective is 0.00086
#   got page dims 1.489712323028384 x 1.8844578624526604
#   output will be 528x656
# Total preprocess time: 0.08184s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5360.JPG
# Loaded IMG_5360.JPG at size='536x670' --> resized='536x670'
# 670 536
#   got 71 spans with 251 points.
#   initial objective is 0.0010662286349772735
#   optimizing 330 parameters...
#   optimization took 0.86 sec.
#   final objective is 0.00095
#   got page dims 1.547968752618441 x 1.8881898492667477
#   output will be 528x640
# Total preprocess time: 1.13040s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5254.JPG
# Loaded IMG_5254.JPG at size='542x694' --> resized='542x694'
# 694 542
#   got 80 spans with 385 points.
#   initial objective is 0.0019178775180411
#   optimizing 473 parameters...
#   optimization took 1.8 sec.
#   final objective is 0.00182
#   got page dims 1.5085754730082956 x 1.8879724743037514
#   output will be 528x656
# Total preprocess time: 2.11683s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5255.JPG
# Loaded IMG_5255.JPG at size='545x691' --> resized='545x691'
# 691 545
#   got 40 spans with 136 points.
#   initial objective is 0.0003737521180089071
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5302.JPG
# Loaded IMG_5302.JPG at size='538x677' --> resized='538x677'
# 677 538
#   got 35 spans with 181 points.
#   initial objective is 0.0007893299109806998
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5211.JPG
# Loaded IMG_5211.JPG at size='545x691' --> resized='545x691'
# 691 545
#   got 66 spans with 265 points.
#   initial objective is 0.0009146442275709201
#   optimizing 339 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00091
#   got page dims 1.5194611526425517 x 1.8840803079242163
#   output will be 544x656
# Total preprocess time: 0.37579s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5240.JPG
# Loaded IMG_5240.JPG at size='541x675' --> resized='541x675'
# 675 541
#   got 22 spans with 171 points.
#   initial objective is 0.0013003555288705758
#   optimizing 201 parameters...
#   optimization took 0.27 sec.
#   final objective is 0.00123
#   got page dims 1.5529797320385383 x 1.885599363855245
#   output will be 528x640
# Total preprocess time: 0.32062s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5318.JPG
# Loaded IMG_5318.JPG at size='526x697' --> resized='526x697'
# 697 526
#   got 72 spans with 245 points.
#   initial objective is 0.00106757924329154
#   optimizing 325 parameters...
#   optimization took 1.06 sec.
#   final objective is 0.00097
#   got page dims 1.4600253627982867 x 1.886978442760402
#   output will be 528x672
# Total preprocess time: 1.34767s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5235.JPG
# Loaded IMG_5235.JPG at size='537x695' --> resized='537x695'
# 695 537
#   got 20 spans with 165 points.
#   initial objective is 0.0011612102666949935
#   optimizing 193 parameters...
#   optimization took 0.24 sec.
#   final objective is 0.0011
#   got page dims 1.4971791606226474 x 1.8885998914534374
#   output will be 528x656
# Total preprocess time: 0.29063s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5306.JPG
# Loaded IMG_5306.JPG at size='533x705' --> resized='533x705'
# 705 533
#   got 73 spans with 268 points.
#   initial objective is 0.0013676853812266874
#   optimizing 349 parameters...
#   optimization took 1.46 sec.
#   final objective is 0.00122
#   got page dims 1.4686080738015121 x 1.8915100337913349
#   output will be 528x672
# Total preprocess time: 1.71563s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5324.JPG
# Loaded IMG_5324.JPG at size='552x690' --> resized='552x690'
# 690 552
#   got 17 spans with 69 points.
#   initial objective is 0.0003123837117010058
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5352.JPG
# Loaded IMG_5352.JPG at size='542x676' --> resized='542x676'
# 676 542
#   got 20 spans with 156 points.
#   initial objective is 0.0009828772149086847
#   optimizing 184 parameters...
#   optimization took 0.24 sec.
#   final objective is 0.00096
#   got page dims 1.548953729946065 x 1.8824888906965693
#   output will be 528x640
# Total preprocess time: 0.29150s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5299.JPG
# Loaded IMG_5299.JPG at size='529x684' --> resized='529x684'
# 684 529
#   got 74 spans with 294 points.
#   initial objective is 0.0011038806235612198
#   optimizing 376 parameters...
#   optimization took 0.14 sec.
#   final objective is 0.0011
#   got page dims 1.4919647311852944 x 1.885782251709189
#   output will be 528x656
# Total preprocess time: 0.39953s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5268.JPG
# Loaded IMG_5268.JPG at size='536x710' --> resized='536x710'
# 710 536
#   got 83 spans with 319 points.
#   initial objective is 0.0012227064835855117
#   optimizing 410 parameters...
#   optimization took 0.25 sec.
#   final objective is 0.0012
#   got page dims 1.45525147120679 x 1.888384783506647
#   output will be 528x672
# Total preprocess time: 0.58675s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5271.JPG
# Loaded IMG_5271.JPG at size='542x704' --> resized='542x704'
# 704 542
#   got 72 spans with 270 points.
#   initial objective is 0.0011341869089801985
#   optimizing 350 parameters...
#   optimization took 1.15 sec.
#   final objective is 0.00092
#   got page dims 1.4960878701410973 x 1.9005909304864497
#   output will be 528x672
# Total preprocess time: 1.41930s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5263.JPG
# Loaded IMG_5263.JPG at size='544x695' --> resized='544x695'
# 695 544
#   got 70 spans with 273 points.
#   initial objective is 0.001014926474056571
#   optimizing 351 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00101
#   got page dims 1.5100009698505341 x 1.8864728706426908
#   output will be 528x656
# Total preprocess time: 0.36957s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5298.JPG
# Loaded IMG_5298.JPG at size='535x692' --> resized='535x692'
# 692 535
#   got 71 spans with 284 points.
#   initial objective is 0.0011216501747149774
#   optimizing 363 parameters...
#   optimization took 0.13 sec.
#   final objective is 0.00112
#   got page dims 1.4896733114170473 x 1.8852645436230575
#   output will be 528x656
# Total preprocess time: 0.38698s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5206.JPG
# Loaded IMG_5206.JPG at size='533x690' --> resized='533x690'
# 690 533
#   got 63 spans with 243 points.
#   initial objective is 0.000904027279336191
#   optimizing 314 parameters...
#   optimization took 0.1 sec.
#   final objective is 0.0009
#   got page dims 1.490531455188649 x 1.8867712290984358
#   output will be 528x656
# Total preprocess time: 0.32220s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5265.JPG
# Loaded IMG_5265.JPG at size='537x684' --> resized='537x684'
# 684 537
#   got 72 spans with 230 points.
#   initial objective is 0.000948961381696312
#   optimizing 310 parameters...
#   optimization took 0.15 sec.
#   final objective is 0.00091
#   got page dims 1.5116100744765175 x 1.882612922613127
#   output will be 528x656
# Total preprocess time: 0.42518s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5382.JPG
# Loaded IMG_5382.JPG at size='551x674' --> resized='551x674'
# 674 551
#   got 68 spans with 251 points.
#   initial objective is 0.0008614386499990486
#   optimizing 327 parameters...
#   optimization took 0.11 sec.
#   final objective is 0.00086
#   got page dims 1.579074923858646 x 1.8840574784648347
#   output will be 544x640
# Total preprocess time: 0.37298s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5256.JPG
# Loaded IMG_5256.JPG at size='542x692' --> resized='542x692'
# 692 542
#   got 66 spans with 267 points.
#   initial objective is 0.0008778874845068128
#   optimizing 341 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00087
#   got page dims 1.511323633008453 x 1.8864450601348708
#   output will be 528x656
# Total preprocess time: 0.34056s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5312.JPG
# Loaded IMG_5312.JPG at size='539x696' --> resized='539x696'
# 696 539
#   got 71 spans with 241 points.
#   initial objective is 0.0008649494448230752
#   optimizing 320 parameters...
#   optimization took 0.1 sec.
#   final objective is 0.00085
#   got page dims 1.4963450793730828 x 1.8887326505072577
#   output will be 544x672
# Total preprocess time: 0.38355s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5328.JPG
# Loaded IMG_5328.JPG at size='538x682' --> resized='538x682'
# 682 538
#   got 24 spans with 197 points.
#   initial objective is 0.0013585471436869153
#   optimizing 229 parameters...
#   optimization took 0.34 sec.
#   final objective is 0.0013
#   got page dims 1.5278929417925498 x 1.8874234172341864
#   output will be 544x656
# Total preprocess time: 0.40502s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5327.JPG
# Loaded IMG_5327.JPG at size='535x680' --> resized='535x680'
# 680 535
#   got 16 spans with 68 points.
#   initial objective is 0.0002781197550513995
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5242.JPG
# Loaded IMG_5242.JPG at size='538x701' --> resized='538x701'
# 701 538
#   got 68 spans with 279 points.
#   initial objective is 0.0014354509843106855
#   optimizing 355 parameters...
#   optimization took 0.93 sec.
#   final objective is 0.00132
#   got page dims 1.4895340993208217 x 1.8968344188200854
#   output will be 528x672
# Total preprocess time: 1.21379s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5229.JPG
# Loaded IMG_5229.JPG at size='538x672' --> resized='538x672'
# 672 538
#   got 67 spans with 243 points.
#   initial objective is 0.0009762148329067466
#   optimizing 318 parameters...
#   optimization took 0.98 sec.
#   final objective is 0.00087
#   got page dims 1.5524132046568364 x 1.8909522388882751
#   output will be 528x640
# Total preprocess time: 1.23861s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5295.JPG
# Loaded IMG_5295.JPG at size='524x688' --> resized='524x688'
# 688 524
#   got 23 spans with 187 points.
#   initial objective is 0.0012196445069355963
#   optimizing 218 parameters...
#   optimization took 0.28 sec.
#   final objective is 0.00119
#   got page dims 1.4697192290522532 x 1.8859485755355427
#   output will be 512x656
# Total preprocess time: 0.33661s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5396.JPG
# Loaded IMG_5396.JPG at size='545x651' --> resized='545x651'
# 651 545
#   got 19 spans with 137 points.
#   initial objective is 0.0010946579272139698
#   optimizing 164 parameters...
#   optimization took 0.21 sec.
#   final objective is 0.00105
#   got page dims 1.6237423414537386 x 1.8828932265750185
#   output will be 544x624
# Total preprocess time: 0.25723s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5398.JPG
# Loaded IMG_5398.JPG at size='536x667' --> resized='536x667'
# 667 536
#   got 66 spans with 265 points.
#   initial objective is 0.001035044354942611
#   optimizing 339 parameters...
#   optimization took 0.05 sec.
#   final objective is 0.00103
#   got page dims 1.5486637304554844 x 1.8812046317177573
#   output will be 528x640
# Total preprocess time: 0.25027s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5321.JPG
# Loaded IMG_5321.JPG at size='569x666' --> resized='569x666'
# 666 569
#   got 68 spans with 296 points.
#   initial objective is 0.0012518854849814473
#   optimizing 372 parameters...
#   optimization took 1.16 sec.
#   final objective is 0.0012
#   got page dims 1.654491254178806 x 1.8843406599352461
#   output will be 576x640
# Total preprocess time: 1.39509s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5316.JPG
# Loaded IMG_5316.JPG at size='543x691' --> resized='543x691'
# 691 543
#   got 71 spans with 265 points.
#   initial objective is 0.0009464614530616073
#   optimizing 344 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00094
#   got page dims 1.5161907018607759 x 1.886022338000837
#   output will be 528x656
# Total preprocess time: 0.38143s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5288.JPG
# Loaded IMG_5288.JPG at size='549x690' --> resized='549x690'
# 690 549
#   got 69 spans with 253 points.
#   initial objective is 0.0008243924002647475
#   optimizing 330 parameters...
#   optimization took 0.11 sec.
#   final objective is 0.00081
#   got page dims 1.5382772341875657 x 1.8878942992873038
#   output will be 544x656
# Total preprocess time: 0.37209s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5395.JPG
# Loaded IMG_5395.JPG at size='548x655' --> resized='548x655'
# 655 548
#   got 23 spans with 177 points.
#   initial objective is 0.0013836888939270334
#   optimizing 208 parameters...
#   optimization took 0.53 sec.
#   final objective is 0.00122
#   got page dims 1.6159761573603502 x 1.8786559442644934
#   output will be 544x624
# Total preprocess time: 0.60493s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5344.JPG
# Loaded IMG_5344.JPG at size='530x696' --> resized='530x696'
# 696 530
#   got 30 spans with 121 points.
#   initial objective is 0.000574151000251805
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5372.JPG
# Loaded IMG_5372.JPG at size='529x652' --> resized='529x652'
# 652 529
#   got 34 spans with 210 points.
#   initial objective is 0.001245379238186769
#   optimizing 252 parameters...
#   optimization took 0.47 sec.
#   final objective is 0.00118
#   got page dims 1.5705914760732145 x 1.8858278401576956
#   output will be 528x624
# Total preprocess time: 0.56565s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5251.JPG
# Loaded IMG_5251.JPG at size='547x686' --> resized='547x686'
# 686 547
#   got 17 spans with 128 points.
#   initial objective is 0.0007150040214176415
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5249.JPG
# Loaded IMG_5249.JPG at size='557x716' --> resized='557x716'
# 716 557
#   got 71 spans with 269 points.
#   initial objective is 0.0010652200143849713
#   optimizing 348 parameters...
#   optimization took 1.42 sec.
#   final objective is 0.00095
#   got page dims 1.5057495562272087 x 1.885126883775029
#   output will be 560x688
# Total preprocess time: 1.71563s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5377.JPG
# Loaded IMG_5377.JPG at size='536x677' --> resized='536x677'
# 677 536
#   got 80 spans with 317 points.
#   initial objective is 0.0011996043599735086
#   optimizing 405 parameters...
#   optimization took 1.03 sec.
#   final objective is 0.00113
#   got page dims 1.526326912199405 x 1.8831830339244862
#   output will be 528x640
# Total preprocess time: 1.32177s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5311.JPG
# Loaded IMG_5311.JPG at size='540x683' --> resized='540x683'
# 683 540
#   got 72 spans with 242 points.
#   initial objective is 0.0009961616459068093
#   optimizing 322 parameters...
#   optimization took 0.63 sec.
#   final objective is 0.00091
#   got page dims 1.528132990883743 x 1.8869322870900809
#   output will be 544x656
# Total preprocess time: 0.90062s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5221.JPG
# Loaded IMG_5221.JPG at size='537x681' --> resized='537x681'
# 681 537
#   got 81 spans with 332 points.
#   initial objective is 0.0012180047613712568
#   optimizing 421 parameters...
#   optimization took 2.12 sec.
#   final objective is 0.00113
#   got page dims 1.5250267002264124 x 1.8832264860489119
#   output will be 544x656
# Total preprocess time: 2.49010s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5282.JPG
# Loaded IMG_5282.JPG at size='549x691' --> resized='549x691'
# 691 549
#   got 73 spans with 245 points.
#   initial objective is 0.0009597054393134853
#   optimizing 326 parameters...
#   optimization took 0.66 sec.
#   final objective is 0.00087
#   got page dims 1.5345465141453163 x 1.8863413869019154
#   output will be 544x656
# Total preprocess time: 0.95557s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5310.JPG
# Loaded IMG_5310.JPG at size='553x703' --> resized='553x703'
# 703 553
#   got 67 spans with 251 points.
#   initial objective is 0.0008882667542722567
#   optimizing 326 parameters...
#   optimization took 0.11 sec.
#   final objective is 0.00088
#   got page dims 1.5165828352641402 x 1.8862773367904218
#   output will be 544x672
# Total preprocess time: 0.32706s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5394.JPG
# Loaded IMG_5394.JPG at size='554x671' --> resized='554x671'
# 671 554
#   got 66 spans with 231 points.
#   initial objective is 0.0006896440989913282
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5389.JPG
# Loaded IMG_5389.JPG at size='538x680' --> resized='538x680'
# 680 538
#   got 71 spans with 287 points.
#   initial objective is 0.001052121782309559
#   optimizing 366 parameters...
#   optimization took 0.15 sec.
#   final objective is 0.00105
#   got page dims 1.5254253780814648 x 1.883806472057869
#   output will be 528x640
# Total preprocess time: 0.47561s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5358.JPG
# Loaded IMG_5358.JPG at size='541x661' --> resized='541x661'
# 661 541
#   got 78 spans with 315 points.
#   initial objective is 0.0012569471050822233
#   optimizing 401 parameters...
#   optimization took 1.3 sec.
#   final objective is 0.00117
#   got page dims 1.5792413493479367 x 1.8809120710651999
#   output will be 528x624
# Total preprocess time: 1.62899s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5301.JPG
# Loaded IMG_5301.JPG at size='531x697' --> resized='531x697'
# 697 531
#   got 73 spans with 280 points.
#   initial objective is 0.0009956737212872772
#   optimizing 361 parameters...
#   optimization took 0.13 sec.
#   final objective is 0.00099
#   got page dims 1.4669377545244704 x 1.885597584772435
#   output will be 528x672
# Total preprocess time: 0.39953s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5294.JPG
# Loaded IMG_5294.JPG at size='543x693' --> resized='543x693'
# 693 543
#   got 74 spans with 250 points.
#   initial objective is 0.0011457201977900853
#   optimizing 332 parameters...
#   optimization took 0.81 sec.
#   final objective is 0.00103
#   got page dims 1.512940194855585 x 1.8858052941835806
#   output will be 528x656
# Total preprocess time: 1.10078s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5357.JPG
# Loaded IMG_5357.JPG at size='537x676' --> resized='537x676'
# 676 537
#   got 77 spans with 380 points.
#   initial objective is 0.0016294458726981878
#   optimizing 465 parameters...
#   optimization took 0.23 sec.
#   final objective is 0.00162
#   got page dims 1.5294905240222318 x 1.8814354660440362
#   output will be 528x640
# Total preprocess time: 0.56157s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5323.JPG
# Loaded IMG_5323.JPG at size='545x687' --> resized='545x687'
# 687 545
#   got 72 spans with 267 points.
#   initial objective is 0.001027913526556999
#   optimizing 347 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00101
#   got page dims 1.5290507502417985 x 1.8839195904591994
#   output will be 544x656
# Total preprocess time: 0.42644s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5393.JPG
# Loaded IMG_5393.JPG at size='535x652' --> resized='535x652'
# 652 535
#   got 29 spans with 200 points.
#   initial objective is 0.0012947765046971303
#   optimizing 237 parameters...
#   optimization took 0.52 sec.
#   final objective is 0.00124
#   got page dims 1.589987960525387 x 1.8824691216469351
#   output will be 528x624
# Total preprocess time: 0.59999s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5303.JPG
# Loaded IMG_5303.JPG at size='546x698' --> resized='546x698'
# 698 546
#   got 69 spans with 270 points.
#   initial objective is 0.0010643657443913448
#   optimizing 347 parameters...
#   optimization took 0.14 sec.
#   final objective is 0.00106
#   got page dims 1.5096022118839474 x 1.8872445223710785
#   output will be 544x672
# Total preprocess time: 0.36849s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5257.JPG
# Loaded IMG_5257.JPG at size='534x705' --> resized='534x705'
# 705 534
#   got 66 spans with 277 points.
#   initial objective is 0.0010400792796334273
#   optimizing 351 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.00104
#   got page dims 1.4609236725076449 x 1.8885770296430047
#   output will be 528x672
# Total preprocess time: 0.41333s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5228.JPG
# Loaded IMG_5228.JPG at size='546x698' --> resized='546x698'
# 698 546
#   got 71 spans with 288 points.
#   initial objective is 0.0010775642842129024
#   optimizing 367 parameters...
#   optimization took 1.66 sec.
#   final objective is 0.00099
#   got page dims 1.5121398914622164 x 1.883745715385242
#   output will be 544x672
# Total preprocess time: 1.96211s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5392.JPG
# Loaded IMG_5392.JPG at size='538x665' --> resized='538x665'
# 665 538
#   got 64 spans with 250 points.
#   initial objective is 0.0009585491872652143
#   optimizing 322 parameters...
#   optimization took 0.05 sec.
#   final objective is 0.00096
#   got page dims 1.558551397698638 x 1.8802011358495296
#   output will be 544x640
# Total preprocess time: 0.26582s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5354.JPG
# Loaded IMG_5354.JPG at size='528x673' --> resized='528x673'
# 673 528
#   got 75 spans with 318 points.
#   initial objective is 0.001218519848964478
#   optimizing 401 parameters...
#   optimization took 0.17 sec.
#   final objective is 0.00121
#   got page dims 1.5103719941014224 x 1.881588662813393
#   output will be 528x640
# Total preprocess time: 0.51265s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5287.JPG
# Loaded IMG_5287.JPG at size='538x683' --> resized='538x683'
# 683 538
#   got 32 spans with 172 points.
#   initial objective is 0.0008874222873661284
#   optimizing 212 parameters...
#   optimization took 0.44 sec.
#   final objective is 0.00078
#   got page dims 1.5258818451669862 x 1.889278753328488
#   output will be 544x656
# Total preprocess time: 0.53832s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5367.JPG
# Loaded IMG_5367.JPG at size='545x662' --> resized='545x662'
# 662 545
#   got 32 spans with 196 points.
#   initial objective is 0.0012612784872247736
#   optimizing 236 parameters...
#   optimization took 0.5 sec.
#   final objective is 0.00117
#   got page dims 1.5922850809697968 x 1.8826060651355263
#   output will be 528x624
# Total preprocess time: 0.60555s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5319.JPG
# Loaded IMG_5319.JPG at size='568x667' --> resized='568x667'
# 667 568
#   got 65 spans with 256 points.
#   initial objective is 0.0009081500936002445
#   optimizing 329 parameters...
#   optimization took 0.11 sec.
#   final objective is 0.00091
#   got page dims 1.645669833436443 x 1.8821873059788647
#   output will be 560x640
# Total preprocess time: 0.32584s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5290.JPG
# Loaded IMG_5290.JPG at size='540x708' --> resized='540x708'
# 708 540
#   got 76 spans with 312 points.
#   initial objective is 0.0011138438472911758
#   optimizing 396 parameters...
#   optimization took 0.16 sec.
#   final objective is 0.0011
#   got page dims 1.4717091602118735 x 1.8890086611285566
#   output will be 528x672
# Total preprocess time: 0.49142s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5317.JPG
# Loaded IMG_5317.JPG at size='565x707' --> resized='565x707'
# 707 565
#   got 72 spans with 251 points.
#   initial objective is 0.0009061966244302962
#   optimizing 331 parameters...
#   optimization took 0.11 sec.
#   final objective is 0.00088
#   got page dims 1.5442586869228996 x 1.8886709500685424
#   output will be 560x672
# Total preprocess time: 0.40328s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5315.JPG
# Loaded IMG_5315.JPG at size='540x691' --> resized='540x691'
# 691 540
#   got 66 spans with 280 points.
#   initial objective is 0.0011502416139104014
#   optimizing 354 parameters...
#   optimization took 0.95 sec.
#   final objective is 0.0011
#   got page dims 1.5132875361663236 x 1.8928297292766498
#   output will be 528x656
# Total preprocess time: 1.17725s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5219.JPG
# Loaded IMG_5219.JPG at size='544x682' --> resized='544x682'
# 682 544
#   got 72 spans with 255 points.
#   initial objective is 0.0011488814927370474
#   optimizing 335 parameters...
#   optimization took 1.26 sec.
#   final objective is 0.00105
#   got page dims 1.5405048995082231 x 1.8779988890725983
#   output will be 528x640
# Total preprocess time: 1.54024s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5403.JPG
# Loaded IMG_5403.JPG at size='539x633' --> resized='539x633'
# 633 539
#   got 11 spans with 63 points.
#   initial objective is 0.0004749021151169739
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5340.JPG
# Loaded IMG_5340.JPG at size='538x701' --> resized='538x701'
# 701 538
#   got 78 spans with 325 points.
#   initial objective is 0.0012965455836418656
#   optimizing 411 parameters...
#   optimization took 1.05 sec.
#   final objective is 0.00125
#   got page dims 1.4836208504456265 x 1.8901298600589607
#   output will be 528x672
# Total preprocess time: 1.35628s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5239.JPG
# Loaded IMG_5239.JPG at size='548x687' --> resized='548x687'
# 687 548
#   got 69 spans with 265 points.
#   initial objective is 0.000970382440527064
#   optimizing 342 parameters...
#   optimization took 0.24 sec.
#   final objective is 0.00095
#   got page dims 1.541117038194132 x 1.8866415335543043
#   output will be 544x656
# Total preprocess time: 0.52785s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5233.JPG
# Loaded IMG_5233.JPG at size='532x681' --> resized='532x681'
# 681 532
#   got 23 spans with 189 points.
#   initial objective is 0.0012385630948484048
#   optimizing 220 parameters...
#   optimization took 0.22 sec.
#   final objective is 0.00121
#   got page dims 1.5093185154237574 x 1.884736941721836
#   output will be 528x656
# Total preprocess time: 0.28061s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5368.JPG
# Loaded IMG_5368.JPG at size='541x677' --> resized='541x677'
# 677 541
#   got 82 spans with 331 points.
#   initial objective is 0.0013782349737057734
#   optimizing 421 parameters...
#   optimization took 1.47 sec.
#   final objective is 0.00125
#   got page dims 1.541435283816875 x 1.882990778488119
#   output will be 528x640
# Total preprocess time: 1.81113s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5259.JPG
# Loaded IMG_5259.JPG at size='548x709' --> resized='548x709'
# 709 548
#   got 74 spans with 308 points.
#   initial objective is 0.0011757433783553379
#   optimizing 390 parameters...
#   optimization took 1.15 sec.
#   final objective is 0.00111
#   got page dims 1.4967812872548347 x 1.893272193155691
#   output will be 544x672
# Total preprocess time: 1.43879s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5272.JPG
# Loaded IMG_5272.JPG at size='532x681' --> resized='532x681'
# 681 532
#   got 63 spans with 245 points.
#   initial objective is 0.0009525377040537776
#   optimizing 316 parameters...
#   optimization took 0.1 sec.
#   final objective is 0.00095
#   got page dims 1.5052942692575222 x 1.8837420038410793
#   output will be 528x656
# Total preprocess time: 0.33534s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5378.JPG
# Loaded IMG_5378.JPG at size='538x637' --> resized='538x637'
# 637 538
#   got 21 spans with 186 points.
#   initial objective is 0.001344948115657439
#   optimizing 215 parameters...
#   optimization took 0.09 sec.
#   final objective is 0.00134
#   got page dims 1.629140545605248 x 1.8756690546277053
#   output will be 528x608
# Total preprocess time: 0.14797s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5330.JPG
# Loaded IMG_5330.JPG at size='533x673' --> resized='533x673'
# 673 533
#   got 17 spans with 68 points.
#   initial objective is 0.0003495160932208502
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5275.JPG
# Loaded IMG_5275.JPG at size='547x708' --> resized='547x708'
# 708 547
#   got 74 spans with 262 points.
#   initial objective is 0.0009921187905551053
#   optimizing 344 parameters...
#   optimization took 0.18 sec.
#   final objective is 0.00096
#   got page dims 1.4931795242265442 x 1.8902328456569832
#   output will be 544x672
# Total preprocess time: 0.44981s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5400.JPG
# Loaded IMG_5400.JPG at size='547x659' --> resized='547x659'
# 659 547
#   got 66 spans with 261 points.
#   initial objective is 0.0010835732982437407
#   optimizing 335 parameters...
#   optimization took 0.05 sec.
#   final objective is 0.00108
#   got page dims 1.5995113949040254 x 1.878672290238268
#   output will be 544x624
# Total preprocess time: 0.26118s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5246.JPG
# Loaded IMG_5246.JPG at size='537x690' --> resized='537x690'
# 690 537
#   got 25 spans with 180 points.
#   initial objective is 0.0011789449823920034
#   optimizing 213 parameters...
#   optimization took 0.25 sec.
#   final objective is 0.00115
#   got page dims 1.5039026670882136 x 1.8865064810916763
#   output will be 528x656
# Total preprocess time: 0.30486s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5216.JPG
# Loaded IMG_5216.JPG at size='533x688' --> resized='533x688'
# 688 533
#   got 65 spans with 257 points.
#   initial objective is 0.0010704661143492204
#   optimizing 330 parameters...
#   optimization took 0.84 sec.
#   final objective is 0.00101
#   got page dims 1.5004695011948548 x 1.8942995358927688
#   output will be 528x656
# Total preprocess time: 1.03712s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5284.JPG
# Loaded IMG_5284.JPG at size='547x696' --> resized='547x696'
# 696 547
#   got 71 spans with 241 points.
#   initial objective is 0.0009094255855209688
#   optimizing 320 parameters...
#   optimization took 0.17 sec.
#   final objective is 0.00088
#   got page dims 1.518394208582692 x 1.8879770843676176
#   output will be 544x672
# Total preprocess time: 0.44072s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5384.JPG
# Loaded IMG_5384.JPG at size='541x662' --> resized='541x662'
# 662 541
#   got 20 spans with 100 points.
#   initial objective is 0.0005666100761930296
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5366.JPG
# Loaded IMG_5366.JPG at size='554x669' --> resized='554x669'
# 669 554
#   got 32 spans with 204 points.
#   initial objective is 0.001200731608095952
#   optimizing 244 parameters...
#   optimization took 0.63 sec.
#   final objective is 0.00105
#   got page dims 1.6103047449101744 x 1.8944601111889348
#   output will be 544x640
# Total preprocess time: 0.72793s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5278.JPG
# Loaded IMG_5278.JPG at size='541x671' --> resized='541x671'
# 671 541
# ...
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5385.JPG
# Loaded IMG_5385.JPG at size='547x674' --> resized='547x674'
# 674 547
#   got 73 spans with 360 points.
#   initial objective is 0.0016992913215551583
#   optimizing 441 parameters...
#   optimization took 1.37 sec.
#   final objective is 0.00164
#   got page dims 1.569554773987347 x 1.8867195980654448
#   output will be 544x640
# Total preprocess time: 1.67661s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5308.JPG
# Loaded IMG_5308.JPG at size='536x691' --> resized='536x691'
# 691 536
#   got 77 spans with 305 points.
#   initial objective is 0.000977838433853702
#   optimizing 390 parameters...
#   optimization took 0.24 sec.
#   final objective is 0.00096
#   got page dims 1.4976400234190625 x 1.887323974379007
#   output will be 528x656
# Total preprocess time: 0.55329s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5215.JPG
# Loaded IMG_5215.JPG at size='542x674' --> resized='542x674'
# 674 542
#   got 70 spans with 274 points.
#   initial objective is 0.0010549092953249055
#   optimizing 352 parameters...
#   optimization took 1.02 sec.
#   final objective is 0.00098
#   got page dims 1.5560628325233472 x 1.8879754166360165
#   output will be 528x640
# Total preprocess time: 1.26992s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5325.JPG
# Loaded IMG_5325.JPG at size='545x700' --> resized='545x700'
# 700 545
#   got 38 spans with 225 points.
#   initial objective is 0.0015697342680661783
#   optimizing 271 parameters...
#   optimization took 0.76 sec.
#   final objective is 0.00132
#   got page dims 1.5116179313925207 x 1.8934009195632595
#   output will be 544x672
# Total preprocess time: 0.88596s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5332.JPG
# Loaded IMG_5332.JPG at size='538x706' --> resized='538x706'
# 706 538
#   got 84 spans with 383 points.
#   initial objective is 0.001587700967550942
#   optimizing 475 parameters...
#   optimization took 1.6 sec.
#   final objective is 0.00148
#   got page dims 1.473520985003837 x 1.8921964651720729
#   output will be 528x672
# Total preprocess time: 1.93091s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5225.JPG
# Loaded IMG_5225.JPG at size='535x680' --> resized='535x680'
# 680 535
#   got 73 spans with 290 points.
#   initial objective is 0.0011368144503895844
#   optimizing 371 parameters...
#   optimization took 0.14 sec.
#   final objective is 0.00113
#   got page dims 1.514862302694463 x 1.8823605269975883
#   output will be 528x640
# Total preprocess time: 0.40708s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5401.JPG
# Loaded IMG_5401.JPG at size='542x669' --> resized='542x669'
# 669 542
#   got 21 spans with 151 points.
#   initial objective is 0.0008172534435461059
#   optimizing 180 parameters...
#   optimization took 0.06 sec.
#   final objective is 0.00081
#   got page dims 1.5616768301356074 x 1.880421866023521
#   output will be 544x640
# Total preprocess time: 0.11452s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5305.JPG
# Loaded IMG_5305.JPG at size='550x694' --> resized='550x694'
# 694 550
#   got 70 spans with 237 points.
#   initial objective is 0.0007299714918323611
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5291.JPG
# Loaded IMG_5291.JPG at size='543x699' --> resized='543x699'
# 699 543
#   got 72 spans with 315 points.
#   initial objective is 0.001375684569639987
#   optimizing 395 parameters...
#   optimization took 0.15 sec.
#   final objective is 0.00137
#   got page dims 1.4995298010916869 x 1.887921281733
#   output will be 544x672
# Total preprocess time: 0.44258s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5376.JPG
# Loaded IMG_5376.JPG at size='533x677' --> resized='533x677'
# 677 533
#   got 79 spans with 280 points.
#   initial objective is 0.0009627216933410913
#   optimizing 367 parameters...
#   optimization took 0.14 sec.
#   final objective is 0.00094
#   got page dims 1.518956223642249 x 1.8843897074029559
#   output will be 528x640
# Total preprocess time: 0.43410s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5362.JPG
# Loaded IMG_5362.JPG at size='543x662' --> resized='543x662'
# 662 543
#   got 28 spans with 186 points.
#   initial objective is 0.001456090686743547
#   optimizing 222 parameters...
#   optimization took 0.61 sec.
#   final objective is 0.00114
#   got page dims 1.5921277343506632 x 1.8817669241013657
#   output will be 528x624
# Total preprocess time: 0.68834s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5258.JPG
# Loaded IMG_5258.JPG at size='533x682' --> resized='533x682'
# 682 533
#   got 64 spans with 233 points.
#   initial objective is 0.000950006973852536
#   optimizing 305 parameters...
#   optimization took 0.1 sec.
#   final objective is 0.00095
#   got page dims 1.5057649300707825 x 1.8836908789176703
#   output will be 528x656
# Total preprocess time: 0.32278s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5243.JPG
# Loaded IMG_5243.JPG at size='543x680' --> resized='543x680'
# 680 543
#   got 24 spans with 188 points.
#   initial objective is 0.001395190107299443
#   optimizing 220 parameters...
#   optimization took 0.37 sec.
#   final objective is 0.00131
#   got page dims 1.5463931962087647 x 1.8839685292486843
#   output will be 528x640
# Total preprocess time: 0.42979s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5205.JPG
# Loaded IMG_5205.JPG at size='552x695' --> resized='552x695'
# 695 552
#   got 25 spans with 186 points.
#   initial objective is 0.0011945499723055386
#   optimizing 219 parameters...
#   optimization took 0.34 sec.
#   final objective is 0.00114
#   got page dims 1.5362124666272667 x 1.8882837000914552
#   output will be 544x656
# Total preprocess time: 0.40679s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5313.JPG
# Loaded IMG_5313.JPG at size='546x684' --> resized='546x684'
# 684 546
#   got 14 spans with 56 points.
#   initial objective is 0.00025465578239985384
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5345.JPG
# Loaded IMG_5345.JPG at size='539x701' --> resized='539x701'
# 701 539
#   got 73 spans with 312 points.
#   initial objective is 0.0012157962559130617
#   optimizing 393 parameters...
#   optimization took 0.92 sec.
#   final objective is 0.00116
#   got page dims 1.48879334658055 x 1.8930644791632394
#   output will be 528x672
# Total preprocess time: 1.23693s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5277.JPG
# Loaded IMG_5277.JPG at size='542x690' --> resized='542x690'
# 690 542
#   got 64 spans with 276 points.
#   initial objective is 0.0011712910852347252
#   optimizing 348 parameters...
#   optimization took 0.96 sec.
#   final objective is 0.00111
#   got page dims 1.5223537243901997 x 1.8933870640700463
#   output will be 528x656
# Total preprocess time: 1.18565s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5266.JPG
# Loaded IMG_5266.JPG at size='546x683' --> resized='546x683'
# 683 546
#   got 66 spans with 258 points.
#   initial objective is 0.0009776189579315672
#   optimizing 332 parameters...
#   optimization took 0.11 sec.
#   final objective is 0.00097
#   got page dims 1.5416012727891304 x 1.8838860659013918
#   output will be 544x656
# Total preprocess time: 0.31704s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5281.JPG
# Loaded IMG_5281.JPG at size='540x705' --> resized='540x705'
# 705 540
#   got 74 spans with 263 points.
#   initial objective is 0.0010424820078377428
#   optimizing 345 parameters...
#   optimization took 0.18 sec.
#   final objective is 0.00101
#   got page dims 1.480105692710692 x 1.8900379772470928
#   output will be 528x672
# Total preprocess time: 0.47967s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5326.JPG
# Loaded IMG_5326.JPG at size='544x695' --> resized='544x695'
# 695 544
#   got 69 spans with 272 points.
#   initial objective is 0.0009063221309407055
#   optimizing 349 parameters...
#   optimization took 0.12 sec.
#   final objective is 0.0009
#   got page dims 1.5099027587694875 x 1.8864169798548571
#   output will be 528x656
# Total preprocess time: 0.38263s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5237.JPG
# Loaded IMG_5237.JPG at size='541x687' --> resized='541x687'
# 687 541
#   got 18 spans with 85 points.
#   initial objective is 0.00032352238114159997
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5371.JPG
# Loaded IMG_5371.JPG at size='534x642' --> resized='534x642'
# 642 534
#   got 66 spans with 265 points.
#   initial objective is 0.0010332222936617575
#   optimizing 339 parameters...
#   optimization took 0.66 sec.
#   final objective is 0.00101
#   got page dims 1.6042474032488474 x 1.8774696558999333
#   output will be 528x608
# Total preprocess time: 0.89516s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5369.JPG
# Loaded IMG_5369.JPG at size='552x658' --> resized='552x658'
# 658 552
#   got 31 spans with 170 points.
#   initial objective is 0.0010600917972678585
#   optimizing 209 parameters...
#   optimization took 0.32 sec.
#   final objective is 0.00099
#   got page dims 1.62301323190574 x 1.8821010050923486
#   output will be 544x624
# Total preprocess time: 0.41651s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5262.JPG
# Loaded IMG_5262.JPG at size='547x713' --> resized='547x713'
# 713 547
#   got 75 spans with 252 points.
#   initial objective is 0.0010470815259726357
#   optimizing 335 parameters...
#   optimization took 0.17 sec.
#   final objective is 0.001
#   got page dims 1.4868397111174545 x 1.894091995183028
#   output will be 544x688
# Total preprocess time: 0.49972s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5339.JPG
# Loaded IMG_5339.JPG at size='537x722' --> resized='537x722'
# 722 537
#   got 76 spans with 366 points.
#   initial objective is 0.0013704985628972136
#   optimizing 450 parameters...
#   optimization took 0.21 sec.
#   final objective is 0.00137
#   got page dims 1.4344914201928989 x 1.8908775899540031
#   output will be 528x688
# Total preprocess time: 0.50266s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5386.JPG
# Loaded IMG_5386.JPG at size='541x647' --> resized='541x647'
# 647 541
#   got 34 spans with 228 points.
#   initial objective is 0.0014146100328987312
#   optimizing 270 parameters...
#   optimization took 0.8 sec.
#   final objective is 0.0013
#   got page dims 1.6246305637025316 x 1.8774075867785915
#   output will be 528x608
# Total preprocess time: 0.88946s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5359.JPG
# Loaded IMG_5359.JPG at size='538x673' --> resized='538x673'
# 673 538
#   got 81 spans with 332 points.
#   initial objective is 0.0012672618371286624
#   optimizing 421 parameters...
#   optimization took 0.17 sec.
#   final objective is 0.00124
#   got page dims 1.5406171239881208 x 1.8819362691989587
#   output will be 528x640
# Total preprocess time: 0.48732s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5342.JPG
# Loaded IMG_5342.JPG at size='539x695' --> resized='539x695'
# 695 539
#   got 21 spans with 167 points.
#   initial objective is 0.0010343483078510932
#   optimizing 196 parameters...
#   optimization took 0.26 sec.
#   final objective is 0.001
#   got page dims 1.4974234310809682 x 1.8855636397366464
#   output will be 528x656
# Total preprocess time: 0.31003s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5320.JPG
# Loaded IMG_5320.JPG at size='547x666' --> resized='547x666'
# 666 547
#   got 19 spans with 143 points.
#   initial objective is 0.0008678302567135354
#   optimizing 170 parameters...
#   optimization took 0.02 sec.
#   final objective is 0.00087
#   got page dims 1.5846343050424192 x 1.8815895090711916
#   output will be 544x640
# Total preprocess time: 0.06262s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5252.JPG
# Loaded IMG_5252.JPG at size='542x719' --> resized='542x719'
# 719 542
#   got 82 spans with 354 points.
#   initial objective is 0.001595407503866465
#   optimizing 444 parameters...
#   optimization took 2.26 sec.
#   final objective is 0.0014
#   got page dims 1.4616071111978213 x 1.8961461247141274
#   output will be 544x688
# Total preprocess time: 2.57861s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5307.JPG
# Loaded IMG_5307.JPG at size='537x688' --> resized='537x688'
# 688 537
#   got 32 spans with 169 points.
#   initial objective is 0.0007202970793412169
#   skipping optimization because objective is already low
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5388.JPG
# Loaded IMG_5388.JPG at size='551x665' --> resized='551x665'
# 665 551
#   got 36 spans with 214 points.
#   initial objective is 0.001538916882934004
#   optimizing 258 parameters...
#   optimization took 0.79 sec.
#   final objective is 0.00129
#   got page dims 1.606764105033151 x 1.8849677012920987
#   output will be 560x640
# Total preprocess time: 0.89717s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5331.JPG
# Loaded IMG_5331.JPG at size='542x694' --> resized='542x694'
# 694 542
#   got 20 spans with 161 points.
#   initial objective is 0.0011617399692225934
#   optimizing 189 parameters...
#   optimization took 0.21 sec.
#   final objective is 0.00108
#   got page dims 1.513058289252182 x 1.8878440942060828
#   output will be 528x656
# Total preprocess time: 0.26294s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5361.JPG
# Loaded IMG_5361.JPG at size='534x663' --> resized='534x663'
# 663 534
#   got 68 spans with 259 points.
#   initial objective is 0.001260484115549725
#   optimizing 335 parameters...
#   optimization took 1.19 sec.
#   final objective is 0.00117
#   got page dims 1.5613702162070318 x 1.8848027658073065
#   output will be 528x624
# Total preprocess time: 1.47761s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5209.JPG
# Loaded IMG_5209.JPG at size='538x705' --> resized='538x705'
# 705 538
#   got 82 spans with 306 points.
#   initial objective is 0.0011755420096766908
#   optimizing 396 parameters...
#   optimization took 1.8 sec.
#   final objective is 0.00109
#   got page dims 1.4889533778786919 x 1.9069874768337387
#   output will be 528x672
# Total preprocess time: 2.10605s
# ------------------------------
# Processing /home/asus/stuDYING/IT/Thesis/from_server/heic_fol/130124/IMG_5387.JPG
# Loaded IMG_5387.JPG at size='541x649' --> resized='541x649'
# 649 541
#   got 30 spans with 217 points.
#   initial objective is 0.0012528783198702074
#   optimizing 255 parameters...
#   optimization took 0.6 sec.
#   final objective is 0.00122
#   got page dims 1.616015916922169 x 1.8809215263867822
#   output will be 544x624
# Total preprocess time: 0.69582s
